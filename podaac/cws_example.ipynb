# %% [markdown]
# # PO.DAAC Web Services Example
#
# Notebook version of the example of the PO.DACC Web Services worfklow:
#
# https://podaac.jpl.nasa.gov/ws
#
# > This example python script shows an entire subsetting workflow using the PO.DAAC Web Services, exercising several of the services: datasets are searched (Dataset Search); variables in the found datasets are identified (Dataset Variables); granules meeting search criteria are found (Granule Search); and the identified granules are subsetted (Granule Subset). Before running this script, email_address variable need to be changed to a valid email address to receive the result.

# %% [markdown]
# ## Install and load dependencies
#
# `feedparser` is the only dependence that is not part of the standard library. It is available on [PyPi](https://pypi.python.org/pypi/feedparser) and can be installed using `pip`.
#
#     pip install feedparser --user

# %%
import feedparser
import httplib
import json
import os
import time
import urllib
from zipfile import ZipFile

# %% [markdown]
# ## Search qualifiers

# %%
start_time = '2014-06-02T05:31:00Z'
stop_time = '2014-06-02T11:45:30Z'
bounding_box = '-175,-23,-100,23' #something like the tropical pacific

# %% [markdown]
# ## Search for available datasets

# %%
cws_ds_search = 'https://podaac.jpl.nasa.gov/ws/search/dataset?'
#following are the attributes that define the search
ds_search_args = { 'processLevel' : '2', 'satellite' : 'AQUARIUS_SAC-D' }
search_url = cws_ds_search + urllib.urlencode(ds_search_args)
datasets = feedparser.parse(search_url)

# %%
datasets
# Out:
# {'bozo': 0,
#  'encoding': u'utf-8',
#  'entries': [{'content': [{'base': u'https://podaac.jpl.nasa.gov/ws/search/dataset?satellite=AQUARIUS_SAC-D&processLevel=2',
#      'language': None,
#      'type': u'text/plain',
#      'value': u'The version 4.0 Aquarius CAP Level 2 product contains the third release of the AQUARIUS/SAC-D orbital/swath data based on the Combined Active Passive (CAP) algorithm. CAP is a P.I. produced data set developed and provided by the JPL Climate Oceans and Solid Earth group (S. Yueh).  This Level 2 data set contains sea surface salinity (SSS), wind speed and wind direction data derived from 3 different radiometers and the onboard scatterometer. The CAP algorithm simultaneously retrieves the salinity, wind speed and direction by minimizing the sum of squared differences between model and observations. The main improvement of CAP V4.0 is calibration of the rain roughness correction geophysical model function to HYCOM SSS adjusted by the Rain Impact Model (RIM) to account for rain induced near surface stratification.  Rain-corrected salinity, wind speed and direction data variables are also provided with the CAP V4.0 L2 data. Rain corrected salinity retrieval at L2 is based on collocation with ancillary rain rate from NOAA CMORPH at 0.25 degree and 30 minute resolution, replacing  the  SSMI/S and WindSAT data previously used  for this in CAP V3.0. Each L2 data file covers one 98 minute orbit. The Aquarius instrument is onboard the AQUARIUS/SAC-D satellite, a collaborative effort between NASA and the Argentinian Space Agency Comision Nacional de Actividades Espaciales (CONAE). The instrument consists of three radiometers in push broom alignment at incidence angles of 29, 38, and 46 degrees incidence angles relative to the shadow side of the orbit. Footprints for the beams are: 76 km (along-track) x 94 km (cross-track), 84 km x 120 km and 96km x 156 km, yielding a total cross-track swath of 370 km. The radiometers measure brightness temperature at 1.413 GHz in their respective horizontal and vertical polarizations (TH and TV). A scatterometer operating at 1.26 GHz measures ocean backscatter in each footprint that is used for surface roughness corrections in the estimation of salinity. The scatterometer has an approximate 390km swath.'}],
#    'dcterms_date': u'2011-08-25T00:00:00Z/2015-06-07T12:00:00Z',
#    'dcterms_identifier': u'PODAAC-AQR40-2TOCS',
#    'gml_envelope': u'',
#    'gml_lowercorner': u'-180 -90',
#    'gml_uppercorner': u'180 90',
#    'guidislink': True,
#    'id': u'https://podaac.jpl.nasa.gov/ws/search/PODAAC-AQR40-2TOCS',
#    'link': u'https://podaac.jpl.nasa.gov/ws/search/PODAAC-AQR40-2TOCS',
#    'links': [{'href': u'http://podaac.jpl.nasa.gov/ws/search/dataset?full=true&datasetId=PODAAC-AQR40-2TOCS',
#      'rel': u'enclosure',
#      'title': u'PO.DAAC Metadata',
#      'type': u'application/atom+xml'},
#     {'href': u'http://podaac.jpl.nasa.gov/ws/metadata/dataset?datasetId=PODAAC-AQR40-2TOCS&format=iso',
#      'rel': u'enclosure',
#      'title': u'ISO-19115 Metadata',
#      'type': u'text/xml'},
#     {'href': u'http://podaac.jpl.nasa.gov/ws/metadata/dataset?datasetId=PODAAC-AQR40-2TOCS&format=gcmd',
#      'rel': u'enclosure',
#      'title': u'GCMD Metadata',
#      'type': u'text/xml'},
#     {'href': u'http://podaac.jpl.nasa.gov/ws/search/granule?datasetId=PODAAC-AQR40-2TOCS',
#      'rel': u'search',
#      'title': u'Granule Search',
#      'type': u'application/atom+xml'},
#     {'href': u'https://podaac.jpl.nasa.gov/Podaac/thumbnails/AQUARIUS_L2_SSS_CAP_V4.jpg',
#      'rel': u'enclosure',
#      'title': u'Thumbnail',
#      'type': u'image/jpg'},
#     {'href': u'https://podaac-opendap.jpl.nasa.gov/opendap/allData/aquarius/L2/CAPv4/',
#      'rel': u'enclosure',
#      'title': u'OPeNDAP URL',
#      'type': u'text/html'},
#     {'href': u'ftp://podaac-ftp.jpl.nasa.gov/allData/aquarius/L2/CAPv4',
#      'rel': u'enclosure',
#      'title': u'FTP URL',
#      'type': u'text/plain'},
#     {'href': u'http://podaac.jpl.nasa.gov/dataset/AQUARIUS_L2_SSS_CAP_V4',
#      'rel': u'enclosure',
#      'title': u'Dataset Information',
#      'type': u'text/html'}],
#    'podaac_datasetid': u'PODAAC-AQR40-2TOCS',
#    'podaac_shortname': u'AQUARIUS_L2_SSS_CAP_V4',
#    'summary': u'The version 4.0 Aquarius CAP Level 2 product contains the third release of the AQUARIUS/SAC-D orbital/swath data based on the Combined Active Passive (CAP) algorithm. CAP is a P.I. produced data set developed and provided by the JPL Climate Oceans and Solid Earth group (S. Yueh).  This Level 2 data set contains sea surface salinity (SSS), wind speed and wind direction data derived from 3 different radiometers and the onboard scatterometer. The CAP algorithm simultaneously retrieves the salinity, wind speed and direction by minimizing the sum of squared differences between model and observations. The main improvement of CAP V4.0 is calibration of the rain roughness correction geophysical model function to HYCOM SSS adjusted by the Rain Impact Model (RIM) to account for rain induced near surface stratification.  Rain-corrected salinity, wind speed and direction data variables are also provided with the CAP V4.0 L2 data. Rain corrected salinity retrieval at L2 is based on collocation with ancillary rain rate from NOAA CMORPH at 0.25 degree and 30 minute resolution, replacing  the  SSMI/S and WindSAT data previously used  for this in CAP V3.0. Each L2 data file covers one 98 minute orbit. The Aquarius instrument is onboard the AQUARIUS/SAC-D satellite, a collaborative effort between NASA and the Argentinian Space Agency Comision Nacional de Actividades Espaciales (CONAE). The instrument consists of three radiometers in push broom alignment at incidence angles of 29, 38, and 46 degrees incidence angles relative to the shadow side of the orbit. Footprints for the beams are: 76 km (along-track) x 94 km (cross-track), 84 km x 120 km and 96km x 156 km, yielding a total cross-track swath of 370 km. The radiometers measure brightness temperature at 1.413 GHz in their respective horizontal and vertical polarizations (TH and TV). A scatterometer operating at 1.26 GHz measures ocean backscatter in each footprint that is used for surface roughness corrections in the estimation of salinity. The scatterometer has an approximate 390km swath.',
#    'time_end': u'2015-06-07T12:00:00Z',
#    'time_start': u'2011-08-25T00:00:00Z',
#    'title': u'Aquarius CAP Level 2 Sea Surface Salinity, Wind Speed &amp; Direction Data V4.0',
#    'title_detail': {'base': u'https://podaac.jpl.nasa.gov/ws/search/dataset?satellite=AQUARIUS_SAC-D&processLevel=2',
#     'language': None,
#     'type': u'text/plain',
#     'value': u'Aquarius CAP Level 2 Sea Surface Salinity, Wind Speed &amp; Direction Data V4.0'},
#    'updated': u'2017-04-28T05:01:46Z',
#    'updated_parsed': time.struct_time(tm_year=2017, tm_mon=4, tm_mday=28, tm_hour=5, tm_min=1, tm_sec=46, tm_wday=4, tm_yday=118, tm_isdst=0),
#    'where': {}},
#   {'content': [{'base': u'https://podaac.jpl.nasa.gov/ws/search/dataset?satellite=AQUARIUS_SAC-D&processLevel=2',
#      'language': None,
#      'type': u'text/plain',
#      'value': u'The version 5.0 Aquarius Level 2 product Cal product includes only the instrumental wiggle correction and is part of the official end of mission release of the orbital/swath data from AQUARIUS/SAC-D mission. The Aquarius Level 2 data set contains sea surface salinity (SSS) and wind speed data derived from 3 different radiometers and the onboard scatterometer. Included also in the Level 2 data are the horizontal and vertical brightness temperatures (TH and TV) for each radiometer, ancillary data,\nflags, converted telemetry and navigation data. Each data file covers one 98 minute orbit. The Aquarius instrument is onboard the AQUARIUS/SAC-D satellite, a collaborative effort between NASA and the Argentinian Space Agency Comision Nacional de Actividades Espaciales (CONAE). The instrument consists of three radiometers in push broom alignment at incidence angles of 29, 38, and 46 degrees incidence angles relative to the shadow side of the orbit. Footprints for the beams are: 76 km (along-track) x 94 km (cross-track), 84 km x 120 km and 96km x 156 km, yielding a total cross-track swath of 370 km. The radiometers measure brightness temperature at 1.413 GHz in their respective horizontal and vertical polarizations (TH and TV). A scatterometer operating at 1.26 GHz measures ocean backscatter in each footprint that is used for surface roughness corrections in the estimation of salinity. The scatterometer has an approximate 390km swath. Enhancements to the version 5.0 Level 2 data relative to v4.0 include: improvement of the salinity retrieval geophysical model for SST bias, estimates of SSS uncertainties (systematic and random components), and inclusion of a new spiciness variable.'}],
#    'dcterms_date': u'2011-08-25T00:00:00Z/2015-06-07T12:51:00Z',
#    'dcterms_identifier': u'PODAAC-AQR50-2IOCS',
#    'gml_envelope': u'',
#    'gml_lowercorner': u'-180 -90',
#    'gml_uppercorner': u'180 90',
#    'guidislink': True,
#    'id': u'https://podaac.jpl.nasa.gov/ws/search/PODAAC-AQR50-2IOCS',
#    'link': u'https://podaac.jpl.nasa.gov/ws/search/PODAAC-AQR50-2IOCS',
#    'links': [{'href': u'http://podaac.jpl.nasa.gov/ws/search/dataset?full=true&datasetId=PODAAC-AQR50-2IOCS',
#      'rel': u'enclosure',
#      'title': u'PO.DAAC Metadata',
#      'type': u'application/atom+xml'},
#     {'href': u'http://podaac.jpl.nasa.gov/ws/metadata/dataset?datasetId=PODAAC-AQR50-2IOCS&format=iso',
#      'rel': u'enclosure',
#      'title': u'ISO-19115 Metadata',
#      'type': u'text/xml'},
#     {'href': u'http://podaac.jpl.nasa.gov/ws/metadata/dataset?datasetId=PODAAC-AQR50-2IOCS&format=gcmd',
#      'rel': u'enclosure',
#      'title': u'GCMD Metadata',
#      'type': u'text/xml'},
#     {'href': u'http://podaac.jpl.nasa.gov/ws/search/granule?datasetId=PODAAC-AQR50-2IOCS',
#      'rel': u'search',
#      'title': u'Granule Search',
#      'type': u'application/atom+xml'},
#     {'href': u'https://podaac.jpl.nasa.gov/Podaac/thumbnails/AQUARIUS_L2_SSS_CAL_V5.jpg',
#      'rel': u'enclosure',
#      'title': u'Thumbnail',
#      'type': u'image/jpg'},
#     {'href': u'https://podaac-opendap.jpl.nasa.gov/opendap/allData/aquarius/L2/V5/CAL/',
#      'rel': u'enclosure',
#      'title': u'OPeNDAP URL',
#      'type': u'text/html'},
#     {'href': u'ftp://podaac-ftp.jpl.nasa.gov/allData/aquarius/L2/V5/CAL',
#      'rel': u'enclosure',
#      'title': u'FTP URL',
#      'type': u'text/plain'},
#     {'href': u'http://podaac.jpl.nasa.gov/dataset/AQUARIUS_L2_SSS_CAL_V5',
#      'rel': u'enclosure',
#      'title': u'Dataset Information',
#      'type': u'text/html'}],
#    'podaac_datasetid': u'PODAAC-AQR50-2IOCS',
#    'podaac_shortname': u'AQUARIUS_L2_SSS_CAL_V5',
#    'summary': u'The version 5.0 Aquarius Level 2 product Cal product includes only the instrumental wiggle correction and is part of the official end of mission release of the orbital/swath data from AQUARIUS/SAC-D mission. The Aquarius Level 2 data set contains sea surface salinity (SSS) and wind speed data derived from 3 different radiometers and the onboard scatterometer. Included also in the Level 2 data are the horizontal and vertical brightness temperatures (TH and TV) for each radiometer, ancillary data,\nflags, converted telemetry and navigation data. Each data file covers one 98 minute orbit. The Aquarius instrument is onboard the AQUARIUS/SAC-D satellite, a collaborative effort between NASA and the Argentinian Space Agency Comision Nacional de Actividades Espaciales (CONAE). The instrument consists of three radiometers in push broom alignment at incidence angles of 29, 38, and 46 degrees incidence angles relative to the shadow side of the orbit. Footprints for the beams are: 76 km (along-track) x 94 km (cross-track), 84 km x 120 km and 96km x 156 km, yielding a total cross-track swath of 370 km. The radiometers measure brightness temperature at 1.413 GHz in their respective horizontal and vertical polarizations (TH and TV). A scatterometer operating at 1.26 GHz measures ocean backscatter in each footprint that is used for surface roughness corrections in the estimation of salinity. The scatterometer has an approximate 390km swath. Enhancements to the version 5.0 Level 2 data relative to v4.0 include: improvement of the salinity retrieval geophysical model for SST bias, estimates of SSS uncertainties (systematic and random components), and inclusion of a new spiciness variable.',
#    'time_end': u'2015-06-07T12:51:00Z',
#    'time_start': u'2011-08-25T00:00:00Z',
#    'title': u'Aquarius Official Release Level 2 Sea Surface Salinity &amp; Wind Speed Cal Data V5.0',
#    'title_detail': {'base': u'https://podaac.jpl.nasa.gov/ws/search/dataset?satellite=AQUARIUS_SAC-D&processLevel=2',
#     'language': None,
#     'type': u'text/plain',
#     'value': u'Aquarius Official Release Level 2 Sea Surface Salinity &amp; Wind Speed Cal Data V5.0'},
#    'updated': u'2017-12-07T07:31:31Z',
#    'updated_parsed': time.struct_time(tm_year=2017, tm_mon=12, tm_mday=7, tm_hour=7, tm_min=31, tm_sec=31, tm_wday=3, tm_yday=341, tm_isdst=0),
#    'where': {}},
#   {'content': [{'base': u'https://podaac.jpl.nasa.gov/ws/search/dataset?satellite=AQUARIUS_SAC-D&processLevel=2',
#      'language': None,
#      'type': u'text/plain',
#      'value': u'The version 5.0 Aquarius Level 2 quicklook product includes the instrumental wiggle correction and exponential drift correction and is part of the official end of mission release of the orbital/swath data from AQUARIUS/SAC-D mission. The Aquarius Level 2 data set contains sea surface salinity (SSS) and wind speed data derived from 3 different radiometers and the onboard scatterometer. Included also in the Level 2 data are the horizontal and vertical brightness temperatures (TH and TV) for each radiometer,\nancillary data, flags, converted telemetry and navigation data. Each data file covers one 98 minute orbit. The Aquarius instrument is onboard the AQUARIUS/SAC-D satellite, a collaborative effort between NASA and the Argentinian Space Agency Comision Nacional de Actividades Espaciales (CONAE). The instrument consists of three radiometers in push broom alignment at incidence angles of 29, 38, and 46 degrees incidence angles relative to the shadow side of the orbit. Footprints for the beams are: 76 km (along-track) x 94 km (cross-track), 84 km x 120 km and 96km x 156 km, yielding a total cross-track swath of 370 km. The radiometers measure brightness temperature at 1.413 GHz in their respective horizontal and vertical polarizations (TH and TV). A scatterometer operating at 1.26 GHz measures ocean backscatter in each footprint that is used for surface roughness corrections in the estimation of salinity. The scatterometer has an approximate 390km swath. Enhancements to the version 5.0 Level 2 data relative to v4.0 include: improvement of the salinity retrieval geophysical model for SST bias, estimates of SSS uncertainties (systematic and random components), and inclusion of a new spiciness variable.'}],
#    'dcterms_date': u'2011-08-25T00:00:00Z/2015-06-07T12:51:00Z',
#    'dcterms_identifier': u'PODAAC-AQR50-2JOCS',
#    'gml_envelope': u'',
#    'gml_lowercorner': u'-180 -90',
#    'gml_uppercorner': u'180 90',
#    'guidislink': True,
#    'id': u'https://podaac.jpl.nasa.gov/ws/search/PODAAC-AQR50-2JOCS',
#    'link': u'https://podaac.jpl.nasa.gov/ws/search/PODAAC-AQR50-2JOCS',
#    'links': [{'href': u'http://podaac.jpl.nasa.gov/ws/search/dataset?full=true&datasetId=PODAAC-AQR50-2JOCS',
#      'rel': u'enclosure',
#      'title': u'PO.DAAC Metadata',
#      'type': u'application/atom+xml'},
#     {'href': u'http://podaac.jpl.nasa.gov/ws/metadata/dataset?datasetId=PODAAC-AQR50-2JOCS&format=iso',
#      'rel': u'enclosure',
#      'title': u'ISO-19115 Metadata',
#      'type': u'text/xml'},
#     {'href': u'http://podaac.jpl.nasa.gov/ws/metadata/dataset?datasetId=PODAAC-AQR50-2JOCS&format=gcmd',
#      'rel': u'enclosure',
#      'title': u'GCMD Metadata',
#      'type': u'text/xml'},
#     {'href': u'http://podaac.jpl.nasa.gov/ws/search/granule?datasetId=PODAAC-AQR50-2JOCS',
#      'rel': u'search',
#      'title': u'Granule Search',
#      'type': u'application/atom+xml'},
#     {'href': u'https://podaac.jpl.nasa.gov/Podaac/thumbnails/AQUARIUS_L2_SSS_QL_V5.jpg',
#      'rel': u'enclosure',
#      'title': u'Thumbnail',
#      'type': u'image/jpg'},
#     {'href': u'https://podaac-opendap.jpl.nasa.gov/opendap/allData/aquarius/L2/V5/QL/',
#      'rel': u'enclosure',
#      'title': u'OPeNDAP URL',
#      'type': u'text/html'},
#     {'href': u'ftp://podaac-ftp.jpl.nasa.gov/allData/aquarius/L2/V5/QL',
#      'rel': u'enclosure',
#      'title': u'FTP URL',
#      'type': u'text/plain'},
#     {'href': u'http://podaac.jpl.nasa.gov/dataset/AQUARIUS_L2_SSS_QL_V5',
#      'rel': u'enclosure',
#      'title': u'Dataset Information',
#      'type': u'text/html'}],
#    'podaac_datasetid': u'PODAAC-AQR50-2JOCS',
#    'podaac_shortname': u'AQUARIUS_L2_SSS_QL_V5',
#    'summary': u'The version 5.0 Aquarius Level 2 quicklook product includes the instrumental wiggle correction and exponential drift correction and is part of the official end of mission release of the orbital/swath data from AQUARIUS/SAC-D mission. The Aquarius Level 2 data set contains sea surface salinity (SSS) and wind speed data derived from 3 different radiometers and the onboard scatterometer. Included also in the Level 2 data are the horizontal and vertical brightness temperatures (TH and TV) for each radiometer,\nancillary data, flags, converted telemetry and navigation data. Each data file covers one 98 minute orbit. The Aquarius instrument is onboard the AQUARIUS/SAC-D satellite, a collaborative effort between NASA and the Argentinian Space Agency Comision Nacional de Actividades Espaciales (CONAE). The instrument consists of three radiometers in push broom alignment at incidence angles of 29, 38, and 46 degrees incidence angles relative to the shadow side of the orbit. Footprints for the beams are: 76 km (along-track) x 94 km (cross-track), 84 km x 120 km and 96km x 156 km, yielding a total cross-track swath of 370 km. The radiometers measure brightness temperature at 1.413 GHz in their respective horizontal and vertical polarizations (TH and TV). A scatterometer operating at 1.26 GHz measures ocean backscatter in each footprint that is used for surface roughness corrections in the estimation of salinity. The scatterometer has an approximate 390km swath. Enhancements to the version 5.0 Level 2 data relative to v4.0 include: improvement of the salinity retrieval geophysical model for SST bias, estimates of SSS uncertainties (systematic and random components), and inclusion of a new spiciness variable.',
#    'time_end': u'2015-06-07T12:51:00Z',
#    'time_start': u'2011-08-25T00:00:00Z',
#    'title': u'Aquarius Official Release Level 2 Sea Surface Salinity &amp; Wind Speed Quicklook Data V5.0',
#    'title_detail': {'base': u'https://podaac.jpl.nasa.gov/ws/search/dataset?satellite=AQUARIUS_SAC-D&processLevel=2',
#     'language': None,
#     'type': u'text/plain',
#     'value': u'Aquarius Official Release Level 2 Sea Surface Salinity &amp; Wind Speed Quicklook Data V5.0'},
#    'updated': u'2017-12-07T07:31:31Z',
#    'updated_parsed': time.struct_time(tm_year=2017, tm_mon=12, tm_mday=7, tm_hour=7, tm_min=31, tm_sec=31, tm_wday=3, tm_yday=341, tm_isdst=0),
#    'where': {}},
#   {'content': [{'base': u'https://podaac.jpl.nasa.gov/ws/search/dataset?satellite=AQUARIUS_SAC-D&processLevel=2',
#      'language': None,
#      'type': u'text/plain',
#      'value': u'The version 5.0 Aquarius Level 2 product is the official third release of the orbital/swath data from AQUARIUS/SAC-D mission. The Aquarius Level 2 data set contains sea surface salinity (SSS) and wind speed data derived from 3 different radiometers and the onboard scatterometer. Included also in the Level 2 data are the horizontal and vertical brightness temperatures (TH and TV) for each radiometer, ancillary data, flags, converted telemetry and navigation data.\nEach data file covers one 98 minute orbit. The Aquarius instrument is onboard the AQUARIUS/SAC-D satellite, a collaborative effort between NASA and the Argentinian Space Agency Comision Nacional de Actividades Espaciales (CONAE). The instrument consists of three radiometers in push broom alignment at incidence angles of 29, 38, and 46 degrees incidence angles relative to the shadow side of the orbit. Footprints for the beams are: 76 km (along-track) x 94 km (cross-track), 84 km x 120 km and 96km x 156 km, yielding a total cross-track swath of 370 km. The radiometers measure brightness temperature at 1.413 GHz in their respective horizontal and vertical polarizations (TH and TV). A scatterometer operating at 1.26 GHz measures ocean backscatter in each footprint that is used for surface roughness corrections in the estimation of salinity. The scatterometer has an approximate 390km swath. Enhancements to the version 5.0 Level 2 data relative to v4.0 include: improvement of the salinity retrieval geophysical model for SST bias, estimates of SSS uncertainties (systematic and random components), and inclusion of a new spiciness variable.'}],
#    'dcterms_date': u'2011-08-25T00:00:00Z/2015-06-07T12:51:00Z',
#    'dcterms_identifier': u'PODAAC-AQR50-2SOCS',
#    'gml_envelope': u'',
#    'gml_lowercorner': u'-180 -90',
#    'gml_uppercorner': u'180 90',
#    'guidislink': True,
#    'id': u'https://podaac.jpl.nasa.gov/ws/search/PODAAC-AQR50-2SOCS',
#    'link': u'https://podaac.jpl.nasa.gov/ws/search/PODAAC-AQR50-2SOCS',
#    'links': [{'href': u'http://podaac.jpl.nasa.gov/ws/search/dataset?full=true&datasetId=PODAAC-AQR50-2SOCS',
#      'rel': u'enclosure',
#      'title': u'PO.DAAC Metadata',
#      'type': u'application/atom+xml'},
#     {'href': u'http://podaac.jpl.nasa.gov/ws/metadata/dataset?datasetId=PODAAC-AQR50-2SOCS&format=iso',
#      'rel': u'enclosure',
#      'title': u'ISO-19115 Metadata',
#      'type': u'text/xml'},
#     {'href': u'http://podaac.jpl.nasa.gov/ws/metadata/dataset?datasetId=PODAAC-AQR50-2SOCS&format=gcmd',
#      'rel': u'enclosure',
#      'title': u'GCMD Metadata',
#      'type': u'text/xml'},
#     {'href': u'http://podaac.jpl.nasa.gov/ws/search/granule?datasetId=PODAAC-AQR50-2SOCS',
#      'rel': u'search',
#      'title': u'Granule Search',
#      'type': u'application/atom+xml'},
#     {'href': u'https://podaac.jpl.nasa.gov/Podaac/thumbnails/AQUARIUS_L2_SSS_V5.jpg',
#      'rel': u'enclosure',
#      'title': u'Thumbnail',
#      'type': u'image/jpg'},
#     {'href': u'https://podaac-opendap.jpl.nasa.gov/opendap/allData/aquarius/L2/V5/SCI/',
#      'rel': u'enclosure',
#      'title': u'OPeNDAP URL',
#      'type': u'text/html'},
#     {'href': u'ftp://podaac-ftp.jpl.nasa.gov/allData/aquarius/L2/V5/SCI',
#      'rel': u'enclosure',
#      'title': u'FTP URL',
#      'type': u'text/plain'},
#     {'href': u'http://podaac.jpl.nasa.gov/dataset/AQUARIUS_L2_SSS_V5',
#      'rel': u'enclosure',
#      'title': u'Dataset Information',
#      'type': u'text/html'}],
#    'podaac_datasetid': u'PODAAC-AQR50-2SOCS',
#    'podaac_shortname': u'AQUARIUS_L2_SSS_V5',
#    'summary': u'The version 5.0 Aquarius Level 2 product is the official third release of the orbital/swath data from AQUARIUS/SAC-D mission. The Aquarius Level 2 data set contains sea surface salinity (SSS) and wind speed data derived from 3 different radiometers and the onboard scatterometer. Included also in the Level 2 data are the horizontal and vertical brightness temperatures (TH and TV) for each radiometer, ancillary data, flags, converted telemetry and navigation data.\nEach data file covers one 98 minute orbit. The Aquarius instrument is onboard the AQUARIUS/SAC-D satellite, a collaborative effort between NASA and the Argentinian Space Agency Comision Nacional de Actividades Espaciales (CONAE). The instrument consists of three radiometers in push broom alignment at incidence angles of 29, 38, and 46 degrees incidence angles relative to the shadow side of the orbit. Footprints for the beams are: 76 km (along-track) x 94 km (cross-track), 84 km x 120 km and 96km x 156 km, yielding a total cross-track swath of 370 km. The radiometers measure brightness temperature at 1.413 GHz in their respective horizontal and vertical polarizations (TH and TV). A scatterometer operating at 1.26 GHz measures ocean backscatter in each footprint that is used for surface roughness corrections in the estimation of salinity. The scatterometer has an approximate 390km swath. Enhancements to the version 5.0 Level 2 data relative to v4.0 include: improvement of the salinity retrieval geophysical model for SST bias, estimates of SSS uncertainties (systematic and random components), and inclusion of a new spiciness variable.',
#    'time_end': u'2015-06-07T12:51:00Z',
#    'time_start': u'2011-08-25T00:00:00Z',
#    'title': u'Aquarius Official Release Level 2 Sea Surface Salinity &amp; Wind Speed Data V5.0',
#    'title_detail': {'base': u'https://podaac.jpl.nasa.gov/ws/search/dataset?satellite=AQUARIUS_SAC-D&processLevel=2',
#     'language': None,
#     'type': u'text/plain',
#     'value': u'Aquarius Official Release Level 2 Sea Surface Salinity &amp; Wind Speed Data V5.0'},
#    'updated': u'2017-12-07T07:31:31Z',
#    'updated_parsed': time.struct_time(tm_year=2017, tm_mon=12, tm_mday=7, tm_hour=7, tm_min=31, tm_sec=31, tm_wday=3, tm_yday=341, tm_isdst=0),
#    'where': {}}],
#  'feed': {'author': u'PO.DAAC Dataset Search Service',
#   'author_detail': {'name': u'PO.DAAC Dataset Search Service'},
#   'authors': [{'name': u'PO.DAAC Dataset Search Service'}],
#   'guidislink': True,
#   'id': u'tag:podaac.jpl.nasa.gov,2018-03-06',
#   'link': u'tag:podaac.jpl.nasa.gov,2018-03-06',
#   'links': [{'href': u'http://podaac.jpl.nasa.gov/ws/search/podaac-granule-osd.xml',
#     'rel': u'search',
#     'type': u'application/opensearchdescription+xml'},
#    {'href': u'http://podaac.jpl.nasa.gov/ws/search/dataset?satellite=AQUARIUS_SAC-D&processLevel=2&startIndex=0',
#     'rel': u'self',
#     'type': u'application/atom+xml'},
#    {'href': u'http://podaac.jpl.nasa.gov/ws/search/dataset?satellite=AQUARIUS_SAC-D&processLevel=2&startIndex=0',
#     'rel': u'first',
#     'type': u'application/atom+xml'}],
#   'opensearch_itemsperpage': u'10',
#   'opensearch_startindex': u'0',
#   'opensearch_totalresults': u'4',
#   'title': u'PO.DAAC Dataset Search Results',
#   'title_detail': {'base': u'https://podaac.jpl.nasa.gov/ws/search/dataset?satellite=AQUARIUS_SAC-D&processLevel=2',
#    'language': None,
#    'type': u'text/plain',
#    'value': u'PO.DAAC Dataset Search Results'},
#   'updated': u'2018-03-06T03:38:20.585423Z',
#   'updated_parsed': time.struct_time(tm_year=2018, tm_mon=3, tm_mday=6, tm_hour=3, tm_min=38, tm_sec=20, tm_wday=1, tm_yday=65, tm_isdst=0)},
#  'headers': {'connection': 'close',
#   'content-type': 'application/xml',
#   'date': 'Tue, 06 Mar 2018 03:38:19 GMT',
#   'server': 'Apache/2.4.6 (Red Hat Enterprise Linux) PHP/7.0.15 OpenSSL/1.0.1e-fips',
#   'strict-transport-security': 'max-age=31536000; includeSubDomains;, max-age=31536000; includeSubDomains;',
#   'transfer-encoding': 'chunked'},
#  'href': u'https://podaac.jpl.nasa.gov/ws/search/dataset?satellite=AQUARIUS_SAC-D&processLevel=2',
#  'namespaces': {'': u'http://www.w3.org/2005/Atom',
#   'dcterms': u'http://purl.org/dc/terms/',
#   'georss': u'http://www.georss.org/georss',
#   'gml': u'http://www.opengis.net/gml',
#   u'opensearch': u'http://a9.com/-/spec/opensearch/1.1/',
#   u'podaac': u'https://podaac.jpl.nasa.gov/opensearch/',
#   u'time': u'http://a9.com/-/opensearch/extensions/time/1.0/'},
#  'status': 200,
#  'version': u'atom10'}

# %%
[(d.podaac_datasetid, d.podaac_shortname) for d in datasets.entries]
# Out:
# [(u'PODAAC-AQR40-2TOCS', u'AQUARIUS_L2_SSS_CAP_V4'),
#  (u'PODAAC-AQR50-2IOCS', u'AQUARIUS_L2_SSS_CAL_V5'),
#  (u'PODAAC-AQR50-2JOCS', u'AQUARIUS_L2_SSS_QL_V5'),
#  (u'PODAAC-AQR50-2SOCS', u'AQUARIUS_L2_SSS_V5')]

# %% [markdown]
# ## Find what are the variables in the last of the 4 datasets

# %%
search_url = 'https://podaac.jpl.nasa.gov/ws/dataset/variables?datasetId=' + datasets.entries[3].podaac_datasetid
search_url
# Out:
# u'https://podaac.jpl.nasa.gov/ws/dataset/variables?datasetId=PODAAC-AQR50-2SOCS'

# %%
search_urlobj = urllib.urlopen(search_url)
variables = json.loads(search_urlobj.read())

# %%
variables
# Out:
# {u'footprint': {u's1': u'0:*,0:0',
#   u's2': u'0:*,*:*',
#   u'strategy': u'periodic'},
#  u'image': {u'ppd': 4, u'res': 8},
#  u'imgVariables': [{u'id': u'Aquarius Data/SSS',
#    u'max': u'40',
#    u'min': u'30',
#    u'palette': u'palette_AQUARIUS_SSS',
#    u'title': u'Sea Surface Salinity',
#    u'units': u'PSU'},
#   {u'id': u'Aquarius Data/density',
#    u'max': u'1030',
#    u'min': u'1012',
#    u'palette': u'paletteMedspirationIndexed',
#    u'title': u'Derived Sea Surface Density',
#    u'units': u'kg/m^3'},
#   {u'id': u'Aquarius Data/SSS_unc_ran',
#    u'max': u'.5',
#    u'min': u'0',
#    u'palette': u'palette_AQUARIUS_SSS',
#    u'title': u'Sea Surface Salinity uncertainty (random)',
#    u'units': u'PSU'},
#   {u'id': u'Aquarius Data/SSS_unc_sys',
#    u'max': u'2',
#    u'min': u'0',
#    u'palette': u'palette_AQUARIUS_SSS',
#    u'title': u'Sea Surface Salinity uncertainty (systematic))',
#    u'units': u'PSU'},
#   {u'id': u'Aquarius Data/anc_SSS_hycom',
#    u'max': u'40',
#    u'min': u'30',
#    u'palette': u'palette_AQUARIUS_SSS',
#    u'title': u'Sea surface salinity (HYCOM)',
#    u'units': u'PSU'},
#   {u'id': u'Aquarius Data/anc_surface_temp',
#    u'max': u'305',
#    u'min': u'275',
#    u'palette': u'paletteMedspirationIndexed',
#    u'title': u'Ancillary Sea Surface Temperature',
#    u'units': u'kelvin'},
#   {u'id': u'Aquarius Data/scat_wind_speed',
#    u'max': u'70',
#    u'min': u'0',
#    u'palette': u'paletteMedspirationIndexed',
#    u'title': u'Scatterometer Wind Speed',
#    u'units': u'm/s'},
#   {u'id': u'Aquarius Data/wind_uncertainty',
#    u'max': u'2.0',
#    u'min': u'0',
#    u'palette': u'paletteMedspirationIndexed',
#    u'title': u'Estimated wind speed error',
#    u'units': u'm/s'},
#   {u'id': u'Aquarius Data/SSS_unc',
#    u'max': u'2.5',
#    u'min': u'0',
#    u'palette': u'palette_AQUARIUS_SSS',
#    u'title': u'SSS Total Uncertainty',
#    u'units': u'PSU'}],
#  u'is360': False,
#  u'latVar': u'Navigation/beam_clat',
#  u'lonVar': u'Navigation/beam_clon',
#  u'tiles': {u'steps': [100, 3, 4]},
#  u'timeVar': u'Block Attributes/secGPS',
#  u'variables': [u'/Aquarius Data/EIA_SSS_sens',
#   u'/Aquarius Data/EIA_err',
#   u'/Aquarius Data/IU_coupling_SSS_sens',
#   u'/Aquarius Data/IU_coupling_err',
#   u'/Aquarius Data/Kpc_HH_ant',
#   u'/Aquarius Data/Kpc_HH_toa',
#   u'/Aquarius Data/Kpc_HV_ant',
#   u'/Aquarius Data/Kpc_HV_toa',
#   u'/Aquarius Data/Kpc_VH_ant',
#   u'/Aquarius Data/Kpc_VH_toa',
#   u'/Aquarius Data/Kpc_VV_ant',
#   u'/Aquarius Data/Kpc_VV_toa',
#   u'/Aquarius Data/Kpc_total',
#   u'/Aquarius Data/NEDT_3_SSS_sens',
#   u'/Aquarius Data/NEDT_3_err',
#   u'/Aquarius Data/NEDT_H_SSS_sens',
#   u'/Aquarius Data/NEDT_H_err',
#   u'/Aquarius Data/NEDT_V_SSS_sens',
#   u'/Aquarius Data/NEDT_V_err',
#   u'/Aquarius Data/RFI_level_SSS_sens',
#   u'/Aquarius Data/RFI_level_err',
#   u'/Aquarius Data/SSS',
#   u'/Aquarius Data/SSS_matchup',
#   u'/Aquarius Data/SSS_nolc',
#   u'/Aquarius Data/SSS_unc',
#   u'/Aquarius Data/SSS_unc_EIA',
#   u'/Aquarius Data/SSS_unc_IU_coupling',
#   u'/Aquarius Data/SSS_unc_NEDT_3',
#   u'/Aquarius Data/SSS_unc_NEDT_H',
#   u'/Aquarius Data/SSS_unc_NEDT_V',
#   u'/Aquarius Data/SSS_unc_RFI_level',
#   u'/Aquarius Data/SSS_unc_TbV_ice_contam',
#   u'/Aquarius Data/SSS_unc_TbV_land_contam',
#   u'/Aquarius Data/SSS_unc_galact_Ta',
#   u'/Aquarius Data/SSS_unc_moon_Ta',
#   u'/Aquarius Data/SSS_unc_ran',
#   u'/Aquarius Data/SSS_unc_surface_temp',
#   u'/Aquarius Data/SSS_unc_sys',
#   u'/Aquarius Data/SSS_unc_wind_dir_rand',
#   u'/Aquarius Data/SSS_unc_wind_speed_rand',
#   u'/Aquarius Data/SSS_unc_wind_speed_syst',
#   u'/Aquarius Data/anc_SSS_argo',
#   u'/Aquarius Data/anc_SSS_hycom',
#   u'/Aquarius Data/anc_Tb_dw',
#   u'/Aquarius Data/anc_Tb_up',
#   u'/Aquarius Data/anc_cwat',
#   u'/Aquarius Data/anc_sm',
#   u'/Aquarius Data/anc_subsurf_temp',
#   u'/Aquarius Data/anc_surface_pressure',
#   u'/Aquarius Data/anc_surface_temp',
#   u'/Aquarius Data/anc_surface_temp_SSS_sens',
#   u'/Aquarius Data/anc_surface_temp_err',
#   u'/Aquarius Data/anc_swe',
#   u'/Aquarius Data/anc_swh',
#   u'/Aquarius Data/anc_trans',
#   u'/Aquarius Data/anc_wind_dir',
#   u'/Aquarius Data/anc_wind_speed',
#   u'/Aquarius Data/density',
#   u'/Aquarius Data/rad_Ta3',
#   u'/Aquarius Data/rad_Ta30',
#   u'/Aquarius Data/rad_TaH',
#   u'/Aquarius Data/rad_TaH0',
#   u'/Aquarius Data/rad_TaV',
#   u'/Aquarius Data/rad_TaV0',
#   u'/Aquarius Data/rad_TbH',
#   u'/Aquarius Data/rad_TbH_nolc',
#   u'/Aquarius Data/rad_TbH_rc',
#   u'/Aquarius Data/rad_TbH_rc_nolc',
#   u'/Aquarius Data/rad_TbV',
#   u'/Aquarius Data/rad_TbV_ice_contam_SSS_sens',
#   u'/Aquarius Data/rad_TbV_ice_contam_err',
#   u'/Aquarius Data/rad_TbV_land_contam_SSS_sens',
#   u'/Aquarius Data/rad_TbV_land_contam_err',
#   u'/Aquarius Data/rad_TbV_nolc',
#   u'/Aquarius Data/rad_TbV_rc',
#   u'/Aquarius Data/rad_TbV_rc_nolc',
#   u'/Aquarius Data/rad_Tb_consistency',
#   u'/Aquarius Data/rad_Tb_consistency_nolc',
#   u'/Aquarius Data/rad_Tf3',
#   u'/Aquarius Data/rad_Tf30',
#   u'/Aquarius Data/rad_TfH',
#   u'/Aquarius Data/rad_TfH0',
#   u'/Aquarius Data/rad_TfV',
#   u'/Aquarius Data/rad_TfV0',
#   u'/Aquarius Data/rad_dtb_sst_wspd_H',
#   u'/Aquarius Data/rad_dtb_sst_wspd_V',
#   u'/Aquarius Data/rad_exp_Ta3',
#   u'/Aquarius Data/rad_exp_Ta3_hhh',
#   u'/Aquarius Data/rad_exp_TaH',
#   u'/Aquarius Data/rad_exp_TaH_hhh',
#   u'/Aquarius Data/rad_exp_TaV',
#   u'/Aquarius Data/rad_exp_TaV_hhh',
#   u'/Aquarius Data/rad_exp_TbH',
#   u'/Aquarius Data/rad_exp_TbH0',
#   u'/Aquarius Data/rad_exp_TbV',
#   u'/Aquarius Data/rad_exp_TbV0',
#   u'/Aquarius Data/rad_far_rot_ang',
#   u'/Aquarius Data/rad_galact_Ta_SSS_sens',
#   u'/Aquarius Data/rad_galact_Ta_dir_3',
#   u'/Aquarius Data/rad_galact_Ta_dir_H',
#   u'/Aquarius Data/rad_galact_Ta_dir_V',
#   u'/Aquarius Data/rad_galact_Ta_err',
#   u'/Aquarius Data/rad_galact_Ta_ref_3',
#   u'/Aquarius Data/rad_galact_Ta_ref_GO_H',
#   u'/Aquarius Data/rad_galact_Ta_ref_GO_V',
#   u'/Aquarius Data/rad_galact_Ta_ref_H',
#   u'/Aquarius Data/rad_galact_Ta_ref_V',
#   u'/Aquarius Data/rad_galact_dTa_H',
#   u'/Aquarius Data/rad_galact_dTa_V',
#   u'/Aquarius Data/rad_geo_rot_ang',
#   u'/Aquarius Data/rad_hh_wind_speed',
#   u'/Aquarius Data/rad_hhh_wind_speed',
#   u'/Aquarius Data/rad_ice_frac',
#   u'/Aquarius Data/rad_land_frac',
#   u'/Aquarius Data/rad_moon_Ta_SSS_sens',
#   u'/Aquarius Data/rad_moon_Ta_err',
#   u'/Aquarius Data/rad_moon_Ta_ref_3',
#   u'/Aquarius Data/rad_moon_Ta_ref_H',
#   u'/Aquarius Data/rad_moon_Ta_ref_V',
#   u'/Aquarius Data/rad_pol_rot_ang',
#   u'/Aquarius Data/rad_solar_Ta_bak_3',
#   u'/Aquarius Data/rad_solar_Ta_bak_H',
#   u'/Aquarius Data/rad_solar_Ta_bak_V',
#   u'/Aquarius Data/rad_solar_Ta_dir_3',
#   u'/Aquarius Data/rad_solar_Ta_dir_H',
#   u'/Aquarius Data/rad_solar_Ta_dir_V',
#   u'/Aquarius Data/rad_solar_Ta_ref_3',
#   u'/Aquarius Data/rad_solar_Ta_ref_H',
#   u'/Aquarius Data/rad_solar_Ta_ref_V',
#   u'/Aquarius Data/rad_toa_H',
#   u'/Aquarius Data/rad_toa_H_nolc',
#   u'/Aquarius Data/rad_toa_V',
#   u'/Aquarius Data/rad_toa_V_nolc',
#   u'/Aquarius Data/rad_toi_3',
#   u'/Aquarius Data/rad_toi_H',
#   u'/Aquarius Data/rad_toi_V',
#   u'/Aquarius Data/rad_wind_dir_rand_SSS_sens',
#   u'/Aquarius Data/rad_wind_dir_rand_err',
#   u'/Aquarius Data/rad_wind_speed_rand_SSS_sens',
#   u'/Aquarius Data/rad_wind_speed_rand_err',
#   u'/Aquarius Data/rad_wind_speed_syst_SSS_sens',
#   u'/Aquarius Data/rad_wind_speed_syst_err',
#   u'/Aquarius Data/rim_anom',
#   u'/Aquarius Data/rim_anom1',
#   u'/Aquarius Data/rim_anom3',
#   u'/Aquarius Data/rim_anom5',
#   u'/Aquarius Data/rim_bf_irr',
#   u'/Aquarius Data/rim_irr',
#   u'/Aquarius Data/rim_pss',
#   u'/Aquarius Data/rim_sss',
#   u'/Aquarius Data/scat_HH_ant',
#   u'/Aquarius Data/scat_HH_exp',
#   u'/Aquarius Data/scat_HH_toa',
#   u'/Aquarius Data/scat_HV_ant',
#   u'/Aquarius Data/scat_HV_exp',
#   u'/Aquarius Data/scat_HV_toa',
#   u'/Aquarius Data/scat_VH_ant',
#   u'/Aquarius Data/scat_VH_exp',
#   u'/Aquarius Data/scat_VH_toa',
#   u'/Aquarius Data/scat_VV_ant',
#   u'/Aquarius Data/scat_VV_exp',
#   u'/Aquarius Data/scat_VV_toa',
#   u'/Aquarius Data/scat_esurf_H',
#   u'/Aquarius Data/scat_esurf_H_uncertainty',
#   u'/Aquarius Data/scat_esurf_V',
#   u'/Aquarius Data/scat_esurf_V_uncertainty',
#   u'/Aquarius Data/scat_ice_frac',
#   u'/Aquarius Data/scat_land_frac',
#   u'/Aquarius Data/scat_tot_toa',
#   u'/Aquarius Data/scat_wind_speed',
#   u'/Aquarius Data/spiciness',
#   u'/Aquarius Data/wind_uncertainty',
#   u'/Aquarius Flags/rad_rfi_flags',
#   u'/Aquarius Flags/radiometer_flags',
#   u'/Aquarius Flags/rim_status_flag',
#   u'/Aquarius Flags/scat_rfi_flags',
#   u'/Aquarius Flags/scatterometer_flags',
#   u'/Block Attributes/rad_samples',
#   u'/Block Attributes/scat_samples',
#   u'/Block Attributes/sec',
#   u'/Block Attributes/secGPS',
#   u'/Block Attributes/solar xray flux',
#   u'/Converted Telemetry/rad_caltemps',
#   u'/Converted Telemetry/rad_ghh',
#   u'/Converted Telemetry/rad_gmm',
#   u'/Converted Telemetry/rad_gpp',
#   u'/Converted Telemetry/rad_gvv',
#   u'/Converted Telemetry/rad_oh',
#   u'/Converted Telemetry/rad_om',
#   u'/Converted Telemetry/rad_op',
#   u'/Converted Telemetry/rad_ov',
#   u'/Navigation/acs_mode',
#   u'/Navigation/att_ang',
#   u'/Navigation/beam_clat',
#   u'/Navigation/beam_clon',
#   u'/Navigation/cellatfoot',
#   u'/Navigation/cellonfoot',
#   u'/Navigation/celphi',
#   u'/Navigation/celtht',
#   u'/Navigation/glxlat',
#   u'/Navigation/glxlon',
#   u'/Navigation/moond',
#   u'/Navigation/moonglt',
#   u'/Navigation/orb_pos',
#   u'/Navigation/orb_vel',
#   u'/Navigation/scalt',
#   u'/Navigation/scat_beam_clat',
#   u'/Navigation/scat_beam_clon',
#   u'/Navigation/scat_latfoot',
#   u'/Navigation/scat_lonfoot',
#   u'/Navigation/scat_polarization_roll',
#   u'/Navigation/sclat',
#   u'/Navigation/sclon',
#   u'/Navigation/sund',
#   u'/Navigation/sunglt',
#   u'/Navigation/sunphi',
#   u'/Navigation/sunr',
#   u'/Navigation/suntht',
#   u'/Navigation/zang']}

# %% [markdown]
# ## Search for granules in the dataset

# %%
cws_gran_search = 'https://podaac.jpl.nasa.gov/ws/search/granule?'
gran_search_args = {'datasetId': d.podaac_datasetid, 'startTime': start_time,
                    'endTime': stop_time, 'itemsPerPage': 350 }
search_url = cws_gran_search + urllib.urlencode(gran_search_args)
granules = feedparser.parse(search_url)

# %%
granules
# Out:
# {'bozo': 0,
#  'encoding': u'utf-8',
#  'entries': [{'dcterms_date': u'2014-06-02T11:41:01.337000Z/2014-06-02T13:17:58.938000Z',
#    'dcterms_identifier': u'PODAAC-AQR50-2SOCS:Q2014153114100.L2_SCI_V5.0',
#    'gml_envelope': u'',
#    'gml_lowercorner': u'-180 -90',
#    'gml_uppercorner': u'180 90',
#    'guidislink': True,
#    'id': u'PODAAC-AQR50-2SOCS:Q2014153114100.L2_SCI_V5.0',
#    'link': u'PODAAC-AQR50-2SOCS:Q2014153114100.L2_SCI_V5.0',
#    'links': [{'href': u'http://podaac.jpl.nasa.gov/ws/search/granule?full=true&granuleName=Q2014153114100.L2_SCI_V5.0&datasetId=PODAAC-AQR50-2SOCS',
#      'rel': u'enclosure',
#      'title': u'PO.DAAC Metadata',
#      'type': u'application/atom+xml'},
#     {'href': u'http://podaac.jpl.nasa.gov/ws/metadata/granule?granuleName=Q2014153114100.L2_SCI_V5.0&datasetId=PODAAC-AQR50-2SOCS&format=iso',
#      'rel': u'enclosure',
#      'title': u'ISO-19115 Metadata',
#      'type': u'text/xml'},
#     {'href': u'http://podaac.jpl.nasa.gov/ws/metadata/granule?granuleName=Q2014153114100.L2_SCI_V5.0&datasetId=PODAAC-AQR50-2SOCS&format=fgdc',
#      'rel': u'enclosure',
#      'title': u'FGDC Metadata',
#      'type': u'text/xml'}],
#    'podaac_datasetid': u'PODAAC-AQR50-2SOCS',
#    'podaac_shortname': u'AQUARIUS_L2_SSS_V5',
#    'time_end': u'2014-06-02T13:17:58.938000Z',
#    'time_start': u'2014-06-02T11:41:01.337000Z',
#    'title': u'Q2014153114100.L2_SCI_V5.0',
#    'title_detail': {'base': u'https://podaac.jpl.nasa.gov/ws/search/granule?endTime=2014-06-02T11%3A45%3A30Z&itemsPerPage=350&startTime=2014-06-02T05%3A31%3A00Z&datasetId=PODAAC-AQR50-2SOCS',
#     'language': None,
#     'type': u'text/plain',
#     'value': u'Q2014153114100.L2_SCI_V5.0'},
#    'updated': u'2014-06-02T11:41:01.337000Z',
#    'updated_parsed': time.struct_time(tm_year=2014, tm_mon=6, tm_mday=2, tm_hour=11, tm_min=41, tm_sec=1, tm_wday=0, tm_yday=153, tm_isdst=0),
#    'where': {}},
#   {'dcterms_date': u'2014-06-02T10:03:00.375000Z/2014-06-02T11:40:59.897000Z',
#    'dcterms_identifier': u'PODAAC-AQR50-2SOCS:Q2014153100300.L2_SCI_V5.0',
#    'gml_envelope': u'',
#    'gml_lowercorner': u'-180 -90',
#    'gml_uppercorner': u'180 90',
#    'guidislink': True,
#    'id': u'PODAAC-AQR50-2SOCS:Q2014153100300.L2_SCI_V5.0',
#    'link': u'PODAAC-AQR50-2SOCS:Q2014153100300.L2_SCI_V5.0',
#    'links': [{'href': u'http://podaac.jpl.nasa.gov/ws/search/granule?full=true&granuleName=Q2014153100300.L2_SCI_V5.0&datasetId=PODAAC-AQR50-2SOCS',
#      'rel': u'enclosure',
#      'title': u'PO.DAAC Metadata',
#      'type': u'application/atom+xml'},
#     {'href': u'http://podaac.jpl.nasa.gov/ws/metadata/granule?granuleName=Q2014153100300.L2_SCI_V5.0&datasetId=PODAAC-AQR50-2SOCS&format=iso',
#      'rel': u'enclosure',
#      'title': u'ISO-19115 Metadata',
#      'type': u'text/xml'},
#     {'href': u'http://podaac.jpl.nasa.gov/ws/metadata/granule?granuleName=Q2014153100300.L2_SCI_V5.0&datasetId=PODAAC-AQR50-2SOCS&format=fgdc',
#      'rel': u'enclosure',
#      'title': u'FGDC Metadata',
#      'type': u'text/xml'}],
#    'podaac_datasetid': u'PODAAC-AQR50-2SOCS',
#    'podaac_shortname': u'AQUARIUS_L2_SSS_V5',
#    'time_end': u'2014-06-02T11:40:59.897000Z',
#    'time_start': u'2014-06-02T10:03:00.375000Z',
#    'title': u'Q2014153100300.L2_SCI_V5.0',
#    'title_detail': {'base': u'https://podaac.jpl.nasa.gov/ws/search/granule?endTime=2014-06-02T11%3A45%3A30Z&itemsPerPage=350&startTime=2014-06-02T05%3A31%3A00Z&datasetId=PODAAC-AQR50-2SOCS',
#     'language': None,
#     'type': u'text/plain',
#     'value': u'Q2014153100300.L2_SCI_V5.0'},
#    'updated': u'2014-06-02T10:03:00.375000Z',
#    'updated_parsed': time.struct_time(tm_year=2014, tm_mon=6, tm_mday=2, tm_hour=10, tm_min=3, tm_sec=0, tm_wday=0, tm_yday=153, tm_isdst=0),
#    'where': {}},
#   {'dcterms_date': u'2014-06-02T08:25:00.854000Z/2014-06-02T10:02:58.935000Z',
#    'dcterms_identifier': u'PODAAC-AQR50-2SOCS:Q2014153082500.L2_SCI_V5.0',
#    'gml_envelope': u'',
#    'gml_lowercorner': u'-180 -90',
#    'gml_uppercorner': u'180 90',
#    'guidislink': True,
#    'id': u'PODAAC-AQR50-2SOCS:Q2014153082500.L2_SCI_V5.0',
#    'link': u'PODAAC-AQR50-2SOCS:Q2014153082500.L2_SCI_V5.0',
#    'links': [{'href': u'http://podaac.jpl.nasa.gov/ws/search/granule?full=true&granuleName=Q2014153082500.L2_SCI_V5.0&datasetId=PODAAC-AQR50-2SOCS',
#      'rel': u'enclosure',
#      'title': u'PO.DAAC Metadata',
#      'type': u'application/atom+xml'},
#     {'href': u'http://podaac.jpl.nasa.gov/ws/metadata/granule?granuleName=Q2014153082500.L2_SCI_V5.0&datasetId=PODAAC-AQR50-2SOCS&format=iso',
#      'rel': u'enclosure',
#      'title': u'ISO-19115 Metadata',
#      'type': u'text/xml'},
#     {'href': u'http://podaac.jpl.nasa.gov/ws/metadata/granule?granuleName=Q2014153082500.L2_SCI_V5.0&datasetId=PODAAC-AQR50-2SOCS&format=fgdc',
#      'rel': u'enclosure',
#      'title': u'FGDC Metadata',
#      'type': u'text/xml'}],
#    'podaac_datasetid': u'PODAAC-AQR50-2SOCS',
#    'podaac_shortname': u'AQUARIUS_L2_SSS_V5',
#    'time_end': u'2014-06-02T10:02:58.935000Z',
#    'time_start': u'2014-06-02T08:25:00.854000Z',
#    'title': u'Q2014153082500.L2_SCI_V5.0',
#    'title_detail': {'base': u'https://podaac.jpl.nasa.gov/ws/search/granule?endTime=2014-06-02T11%3A45%3A30Z&itemsPerPage=350&startTime=2014-06-02T05%3A31%3A00Z&datasetId=PODAAC-AQR50-2SOCS',
#     'language': None,
#     'type': u'text/plain',
#     'value': u'Q2014153082500.L2_SCI_V5.0'},
#    'updated': u'2014-06-02T08:25:00.854000Z',
#    'updated_parsed': time.struct_time(tm_year=2014, tm_mon=6, tm_mday=2, tm_hour=8, tm_min=25, tm_sec=0, tm_wday=0, tm_yday=153, tm_isdst=0),
#    'where': {}},
#   {'dcterms_date': u'2014-06-02T06:47:01.332000Z/2014-06-02T08:24:59.414000Z',
#    'dcterms_identifier': u'PODAAC-AQR50-2SOCS:Q2014153064700.L2_SCI_V5.0',
#    'gml_envelope': u'',
#    'gml_lowercorner': u'-180 -90',
#    'gml_uppercorner': u'180 90',
#    'guidislink': True,
#    'id': u'PODAAC-AQR50-2SOCS:Q2014153064700.L2_SCI_V5.0',
#    'link': u'PODAAC-AQR50-2SOCS:Q2014153064700.L2_SCI_V5.0',
#    'links': [{'href': u'http://podaac.jpl.nasa.gov/ws/search/granule?full=true&granuleName=Q2014153064700.L2_SCI_V5.0&datasetId=PODAAC-AQR50-2SOCS',
#      'rel': u'enclosure',
#      'title': u'PO.DAAC Metadata',
#      'type': u'application/atom+xml'},
#     {'href': u'http://podaac.jpl.nasa.gov/ws/metadata/granule?granuleName=Q2014153064700.L2_SCI_V5.0&datasetId=PODAAC-AQR50-2SOCS&format=iso',
#      'rel': u'enclosure',
#      'title': u'ISO-19115 Metadata',
#      'type': u'text/xml'},
#     {'href': u'http://podaac.jpl.nasa.gov/ws/metadata/granule?granuleName=Q2014153064700.L2_SCI_V5.0&datasetId=PODAAC-AQR50-2SOCS&format=fgdc',
#      'rel': u'enclosure',
#      'title': u'FGDC Metadata',
#      'type': u'text/xml'}],
#    'podaac_datasetid': u'PODAAC-AQR50-2SOCS',
#    'podaac_shortname': u'AQUARIUS_L2_SSS_V5',
#    'time_end': u'2014-06-02T08:24:59.414000Z',
#    'time_start': u'2014-06-02T06:47:01.332000Z',
#    'title': u'Q2014153064700.L2_SCI_V5.0',
#    'title_detail': {'base': u'https://podaac.jpl.nasa.gov/ws/search/granule?endTime=2014-06-02T11%3A45%3A30Z&itemsPerPage=350&startTime=2014-06-02T05%3A31%3A00Z&datasetId=PODAAC-AQR50-2SOCS',
#     'language': None,
#     'type': u'text/plain',
#     'value': u'Q2014153064700.L2_SCI_V5.0'},
#    'updated': u'2014-06-02T06:47:01.332000Z',
#    'updated_parsed': time.struct_time(tm_year=2014, tm_mon=6, tm_mday=2, tm_hour=6, tm_min=47, tm_sec=1, tm_wday=0, tm_yday=153, tm_isdst=0),
#    'where': {}},
#   {'dcterms_date': u'2014-06-02T05:09:00.371000Z/2014-06-02T06:46:59.892000Z',
#    'dcterms_identifier': u'PODAAC-AQR50-2SOCS:Q2014153050900.L2_SCI_V5.0',
#    'gml_envelope': u'',
#    'gml_lowercorner': u'-180 -90',
#    'gml_uppercorner': u'180 90',
#    'guidislink': True,
#    'id': u'PODAAC-AQR50-2SOCS:Q2014153050900.L2_SCI_V5.0',
#    'link': u'PODAAC-AQR50-2SOCS:Q2014153050900.L2_SCI_V5.0',
#    'links': [{'href': u'http://podaac.jpl.nasa.gov/ws/search/granule?full=true&granuleName=Q2014153050900.L2_SCI_V5.0&datasetId=PODAAC-AQR50-2SOCS',
#      'rel': u'enclosure',
#      'title': u'PO.DAAC Metadata',
#      'type': u'application/atom+xml'},
#     {'href': u'http://podaac.jpl.nasa.gov/ws/metadata/granule?granuleName=Q2014153050900.L2_SCI_V5.0&datasetId=PODAAC-AQR50-2SOCS&format=iso',
#      'rel': u'enclosure',
#      'title': u'ISO-19115 Metadata',
#      'type': u'text/xml'},
#     {'href': u'http://podaac.jpl.nasa.gov/ws/metadata/granule?granuleName=Q2014153050900.L2_SCI_V5.0&datasetId=PODAAC-AQR50-2SOCS&format=fgdc',
#      'rel': u'enclosure',
#      'title': u'FGDC Metadata',
#      'type': u'text/xml'}],
#    'podaac_datasetid': u'PODAAC-AQR50-2SOCS',
#    'podaac_shortname': u'AQUARIUS_L2_SSS_V5',
#    'time_end': u'2014-06-02T06:46:59.892000Z',
#    'time_start': u'2014-06-02T05:09:00.371000Z',
#    'title': u'Q2014153050900.L2_SCI_V5.0',
#    'title_detail': {'base': u'https://podaac.jpl.nasa.gov/ws/search/granule?endTime=2014-06-02T11%3A45%3A30Z&itemsPerPage=350&startTime=2014-06-02T05%3A31%3A00Z&datasetId=PODAAC-AQR50-2SOCS',
#     'language': None,
#     'type': u'text/plain',
#     'value': u'Q2014153050900.L2_SCI_V5.0'},
#    'updated': u'2014-06-02T05:09:00.371000Z',
#    'updated_parsed': time.struct_time(tm_year=2014, tm_mon=6, tm_mday=2, tm_hour=5, tm_min=9, tm_sec=0, tm_wday=0, tm_yday=153, tm_isdst=0),
#    'where': {}}],
#  'feed': {'author': u'PO.DAAC Granule Search Service',
#   'author_detail': {'name': u'PO.DAAC Granule Search Service'},
#   'authors': [{'name': u'PO.DAAC Granule Search Service'}],
#   'guidislink': True,
#   'id': u'tag:podaac.jpl.nasa.gov,2018-03-06',
#   'link': u'tag:podaac.jpl.nasa.gov,2018-03-06',
#   'links': [{'href': u'http://podaac.jpl.nasa.gov/ws/search/podaac-dataset-osd.xml',
#     'rel': u'search',
#     'type': u'application/opensearchdescription+xml'},
#    {'href': u'http://podaac.jpl.nasa.gov/ws/search/granule?startIndex=0&endTime=2014-06-02T11%3A45%3A30Z&itemsPerPage=350&datasetId=PODAAC-AQR50-2SOCS&startTime=2014-06-02T05%3A31%3A00Z',
#     'rel': u'self',
#     'type': u'application/atom+xml'},
#    {'href': u'http://podaac.jpl.nasa.gov/ws/search/granule?startIndex=0&endTime=2014-06-02T11%3A45%3A30Z&itemsPerPage=350&datasetId=PODAAC-AQR50-2SOCS&startTime=2014-06-02T05%3A31%3A00Z',
#     'rel': u'first',
#     'type': u'application/atom+xml'}],
#   'opensearch_itemsperpage': u'350',
#   'opensearch_startindex': u'0',
#   'opensearch_totalresults': u'5',
#   'title': u'PO.DAAC Granule Search Results',
#   'title_detail': {'base': u'https://podaac.jpl.nasa.gov/ws/search/granule?endTime=2014-06-02T11%3A45%3A30Z&itemsPerPage=350&startTime=2014-06-02T05%3A31%3A00Z&datasetId=PODAAC-AQR50-2SOCS',
#    'language': None,
#    'type': u'text/plain',
#    'value': u'PO.DAAC Granule Search Results'},
#   'updated': u'2018-03-06T03:38:21.606812Z',
#   'updated_parsed': time.struct_time(tm_year=2018, tm_mon=3, tm_mday=6, tm_hour=3, tm_min=38, tm_sec=21, tm_wday=1, tm_yday=65, tm_isdst=0)},
#  'headers': {'connection': 'close',
#   'content-type': 'application/xml',
#   'date': 'Tue, 06 Mar 2018 03:38:21 GMT',
#   'server': 'Apache/2.4.6 (Red Hat Enterprise Linux) PHP/7.0.15 OpenSSL/1.0.1e-fips',
#   'strict-transport-security': 'max-age=31536000; includeSubDomains;, max-age=31536000; includeSubDomains;',
#   'transfer-encoding': 'chunked'},
#  'href': u'https://podaac.jpl.nasa.gov/ws/search/granule?endTime=2014-06-02T11%3A45%3A30Z&itemsPerPage=350&startTime=2014-06-02T05%3A31%3A00Z&datasetId=PODAAC-AQR50-2SOCS',
#  'namespaces': {'': u'http://www.w3.org/2005/Atom',
#   'dcterms': u'http://purl.org/dc/terms/',
#   'georss': u'http://www.georss.org/georss',
#   'gml': u'http://www.opengis.net/gml',
#   u'opensearch': u'http://a9.com/-/spec/opensearch/1.1/',
#   u'podaac': u'https://podaac.jpl.nasa.gov/opensearch/',
#   u'time': u'http://a9.com/-/opensearch/extensions/time/1.0/'},
#  'status': 200,
#  'version': u'atom10'}

# %%
[(g.title, g.time_start, g.time_end) for g in granules.entries]
# Out:
# [(u'Q2014153114100.L2_SCI_V5.0',
#   u'2014-06-02T11:41:01.337000Z',
#   u'2014-06-02T13:17:58.938000Z'),
#  (u'Q2014153100300.L2_SCI_V5.0',
#   u'2014-06-02T10:03:00.375000Z',
#   u'2014-06-02T11:40:59.897000Z'),
#  (u'Q2014153082500.L2_SCI_V5.0',
#   u'2014-06-02T08:25:00.854000Z',
#   u'2014-06-02T10:02:58.935000Z'),
#  (u'Q2014153064700.L2_SCI_V5.0',
#   u'2014-06-02T06:47:01.332000Z',
#   u'2014-06-02T08:24:59.414000Z'),
#  (u'Q2014153050900.L2_SCI_V5.0',
#   u'2014-06-02T05:09:00.371000Z',
#   u'2014-06-02T06:46:59.892000Z')]

# %%
granules_list = [g.title.encode(encoding='ascii') for g in granules.entries]
granules_list
# Out:
# ['Q2014153114100.L2_SCI_V5.0',
#  'Q2014153100300.L2_SCI_V5.0',
#  'Q2014153082500.L2_SCI_V5.0',
#  'Q2014153064700.L2_SCI_V5.0',
#  'Q2014153050900.L2_SCI_V5.0']

# %% [markdown]
# ## Construct the request dictionary

# %%
request = {'email': '',
           'query': [{'datasetId': d.podaac_datasetid,
                      'compact': 'False',
                      'bbox': bounding_box,
                      'variables' : variables['variables'],
                      'granuleIds' : granules_list }] }
request
# Out:
# {'email': '',
#  'query': [{'bbox': '-175,-23,-100,23',
#    'compact': 'False',
#    'datasetId': u'PODAAC-AQR50-2SOCS',
#    'granuleIds': ['Q2014153114100.L2_SCI_V5.0',
#     'Q2014153100300.L2_SCI_V5.0',
#     'Q2014153082500.L2_SCI_V5.0',
#     'Q2014153064700.L2_SCI_V5.0',
#     'Q2014153050900.L2_SCI_V5.0'],
#    'variables': [u'/Aquarius Data/EIA_SSS_sens',
#     u'/Aquarius Data/EIA_err',
#     u'/Aquarius Data/IU_coupling_SSS_sens',
#     u'/Aquarius Data/IU_coupling_err',
#     u'/Aquarius Data/Kpc_HH_ant',
#     u'/Aquarius Data/Kpc_HH_toa',
#     u'/Aquarius Data/Kpc_HV_ant',
#     u'/Aquarius Data/Kpc_HV_toa',
#     u'/Aquarius Data/Kpc_VH_ant',
#     u'/Aquarius Data/Kpc_VH_toa',
#     u'/Aquarius Data/Kpc_VV_ant',
#     u'/Aquarius Data/Kpc_VV_toa',
#     u'/Aquarius Data/Kpc_total',
#     u'/Aquarius Data/NEDT_3_SSS_sens',
#     u'/Aquarius Data/NEDT_3_err',
#     u'/Aquarius Data/NEDT_H_SSS_sens',
#     u'/Aquarius Data/NEDT_H_err',
#     u'/Aquarius Data/NEDT_V_SSS_sens',
#     u'/Aquarius Data/NEDT_V_err',
#     u'/Aquarius Data/RFI_level_SSS_sens',
#     u'/Aquarius Data/RFI_level_err',
#     u'/Aquarius Data/SSS',
#     u'/Aquarius Data/SSS_matchup',
#     u'/Aquarius Data/SSS_nolc',
#     u'/Aquarius Data/SSS_unc',
#     u'/Aquarius Data/SSS_unc_EIA',
#     u'/Aquarius Data/SSS_unc_IU_coupling',
#     u'/Aquarius Data/SSS_unc_NEDT_3',
#     u'/Aquarius Data/SSS_unc_NEDT_H',
#     u'/Aquarius Data/SSS_unc_NEDT_V',
#     u'/Aquarius Data/SSS_unc_RFI_level',
#     u'/Aquarius Data/SSS_unc_TbV_ice_contam',
#     u'/Aquarius Data/SSS_unc_TbV_land_contam',
#     u'/Aquarius Data/SSS_unc_galact_Ta',
#     u'/Aquarius Data/SSS_unc_moon_Ta',
#     u'/Aquarius Data/SSS_unc_ran',
#     u'/Aquarius Data/SSS_unc_surface_temp',
#     u'/Aquarius Data/SSS_unc_sys',
#     u'/Aquarius Data/SSS_unc_wind_dir_rand',
#     u'/Aquarius Data/SSS_unc_wind_speed_rand',
#     u'/Aquarius Data/SSS_unc_wind_speed_syst',
#     u'/Aquarius Data/anc_SSS_argo',
#     u'/Aquarius Data/anc_SSS_hycom',
#     u'/Aquarius Data/anc_Tb_dw',
#     u'/Aquarius Data/anc_Tb_up',
#     u'/Aquarius Data/anc_cwat',
#     u'/Aquarius Data/anc_sm',
#     u'/Aquarius Data/anc_subsurf_temp',
#     u'/Aquarius Data/anc_surface_pressure',
#     u'/Aquarius Data/anc_surface_temp',
#     u'/Aquarius Data/anc_surface_temp_SSS_sens',
#     u'/Aquarius Data/anc_surface_temp_err',
#     u'/Aquarius Data/anc_swe',
#     u'/Aquarius Data/anc_swh',
#     u'/Aquarius Data/anc_trans',
#     u'/Aquarius Data/anc_wind_dir',
#     u'/Aquarius Data/anc_wind_speed',
#     u'/Aquarius Data/density',
#     u'/Aquarius Data/rad_Ta3',
#     u'/Aquarius Data/rad_Ta30',
#     u'/Aquarius Data/rad_TaH',
#     u'/Aquarius Data/rad_TaH0',
#     u'/Aquarius Data/rad_TaV',
#     u'/Aquarius Data/rad_TaV0',
#     u'/Aquarius Data/rad_TbH',
#     u'/Aquarius Data/rad_TbH_nolc',
#     u'/Aquarius Data/rad_TbH_rc',
#     u'/Aquarius Data/rad_TbH_rc_nolc',
#     u'/Aquarius Data/rad_TbV',
#     u'/Aquarius Data/rad_TbV_ice_contam_SSS_sens',
#     u'/Aquarius Data/rad_TbV_ice_contam_err',
#     u'/Aquarius Data/rad_TbV_land_contam_SSS_sens',
#     u'/Aquarius Data/rad_TbV_land_contam_err',
#     u'/Aquarius Data/rad_TbV_nolc',
#     u'/Aquarius Data/rad_TbV_rc',
#     u'/Aquarius Data/rad_TbV_rc_nolc',
#     u'/Aquarius Data/rad_Tb_consistency',
#     u'/Aquarius Data/rad_Tb_consistency_nolc',
#     u'/Aquarius Data/rad_Tf3',
#     u'/Aquarius Data/rad_Tf30',
#     u'/Aquarius Data/rad_TfH',
#     u'/Aquarius Data/rad_TfH0',
#     u'/Aquarius Data/rad_TfV',
#     u'/Aquarius Data/rad_TfV0',
#     u'/Aquarius Data/rad_dtb_sst_wspd_H',
#     u'/Aquarius Data/rad_dtb_sst_wspd_V',
#     u'/Aquarius Data/rad_exp_Ta3',
#     u'/Aquarius Data/rad_exp_Ta3_hhh',
#     u'/Aquarius Data/rad_exp_TaH',
#     u'/Aquarius Data/rad_exp_TaH_hhh',
#     u'/Aquarius Data/rad_exp_TaV',
#     u'/Aquarius Data/rad_exp_TaV_hhh',
#     u'/Aquarius Data/rad_exp_TbH',
#     u'/Aquarius Data/rad_exp_TbH0',
#     u'/Aquarius Data/rad_exp_TbV',
#     u'/Aquarius Data/rad_exp_TbV0',
#     u'/Aquarius Data/rad_far_rot_ang',
#     u'/Aquarius Data/rad_galact_Ta_SSS_sens',
#     u'/Aquarius Data/rad_galact_Ta_dir_3',
#     u'/Aquarius Data/rad_galact_Ta_dir_H',
#     u'/Aquarius Data/rad_galact_Ta_dir_V',
#     u'/Aquarius Data/rad_galact_Ta_err',
#     u'/Aquarius Data/rad_galact_Ta_ref_3',
#     u'/Aquarius Data/rad_galact_Ta_ref_GO_H',
#     u'/Aquarius Data/rad_galact_Ta_ref_GO_V',
#     u'/Aquarius Data/rad_galact_Ta_ref_H',
#     u'/Aquarius Data/rad_galact_Ta_ref_V',
#     u'/Aquarius Data/rad_galact_dTa_H',
#     u'/Aquarius Data/rad_galact_dTa_V',
#     u'/Aquarius Data/rad_geo_rot_ang',
#     u'/Aquarius Data/rad_hh_wind_speed',
#     u'/Aquarius Data/rad_hhh_wind_speed',
#     u'/Aquarius Data/rad_ice_frac',
#     u'/Aquarius Data/rad_land_frac',
#     u'/Aquarius Data/rad_moon_Ta_SSS_sens',
#     u'/Aquarius Data/rad_moon_Ta_err',
#     u'/Aquarius Data/rad_moon_Ta_ref_3',
#     u'/Aquarius Data/rad_moon_Ta_ref_H',
#     u'/Aquarius Data/rad_moon_Ta_ref_V',
#     u'/Aquarius Data/rad_pol_rot_ang',
#     u'/Aquarius Data/rad_solar_Ta_bak_3',
#     u'/Aquarius Data/rad_solar_Ta_bak_H',
#     u'/Aquarius Data/rad_solar_Ta_bak_V',
#     u'/Aquarius Data/rad_solar_Ta_dir_3',
#     u'/Aquarius Data/rad_solar_Ta_dir_H',
#     u'/Aquarius Data/rad_solar_Ta_dir_V',
#     u'/Aquarius Data/rad_solar_Ta_ref_3',
#     u'/Aquarius Data/rad_solar_Ta_ref_H',
#     u'/Aquarius Data/rad_solar_Ta_ref_V',
#     u'/Aquarius Data/rad_toa_H',
#     u'/Aquarius Data/rad_toa_H_nolc',
#     u'/Aquarius Data/rad_toa_V',
#     u'/Aquarius Data/rad_toa_V_nolc',
#     u'/Aquarius Data/rad_toi_3',
#     u'/Aquarius Data/rad_toi_H',
#     u'/Aquarius Data/rad_toi_V',
#     u'/Aquarius Data/rad_wind_dir_rand_SSS_sens',
#     u'/Aquarius Data/rad_wind_dir_rand_err',
#     u'/Aquarius Data/rad_wind_speed_rand_SSS_sens',
#     u'/Aquarius Data/rad_wind_speed_rand_err',
#     u'/Aquarius Data/rad_wind_speed_syst_SSS_sens',
#     u'/Aquarius Data/rad_wind_speed_syst_err',
#     u'/Aquarius Data/rim_anom',
#     u'/Aquarius Data/rim_anom1',
#     u'/Aquarius Data/rim_anom3',
#     u'/Aquarius Data/rim_anom5',
#     u'/Aquarius Data/rim_bf_irr',
#     u'/Aquarius Data/rim_irr',
#     u'/Aquarius Data/rim_pss',
#     u'/Aquarius Data/rim_sss',
#     u'/Aquarius Data/scat_HH_ant',
#     u'/Aquarius Data/scat_HH_exp',
#     u'/Aquarius Data/scat_HH_toa',
#     u'/Aquarius Data/scat_HV_ant',
#     u'/Aquarius Data/scat_HV_exp',
#     u'/Aquarius Data/scat_HV_toa',
#     u'/Aquarius Data/scat_VH_ant',
#     u'/Aquarius Data/scat_VH_exp',
#     u'/Aquarius Data/scat_VH_toa',
#     u'/Aquarius Data/scat_VV_ant',
#     u'/Aquarius Data/scat_VV_exp',
#     u'/Aquarius Data/scat_VV_toa',
#     u'/Aquarius Data/scat_esurf_H',
#     u'/Aquarius Data/scat_esurf_H_uncertainty',
#     u'/Aquarius Data/scat_esurf_V',
#     u'/Aquarius Data/scat_esurf_V_uncertainty',
#     u'/Aquarius Data/scat_ice_frac',
#     u'/Aquarius Data/scat_land_frac',
#     u'/Aquarius Data/scat_tot_toa',
#     u'/Aquarius Data/scat_wind_speed',
#     u'/Aquarius Data/spiciness',
#     u'/Aquarius Data/wind_uncertainty',
#     u'/Aquarius Flags/rad_rfi_flags',
#     u'/Aquarius Flags/radiometer_flags',
#     u'/Aquarius Flags/rim_status_flag',
#     u'/Aquarius Flags/scat_rfi_flags',
#     u'/Aquarius Flags/scatterometer_flags',
#     u'/Block Attributes/rad_samples',
#     u'/Block Attributes/scat_samples',
#     u'/Block Attributes/sec',
#     u'/Block Attributes/secGPS',
#     u'/Block Attributes/solar xray flux',
#     u'/Converted Telemetry/rad_caltemps',
#     u'/Converted Telemetry/rad_ghh',
#     u'/Converted Telemetry/rad_gmm',
#     u'/Converted Telemetry/rad_gpp',
#     u'/Converted Telemetry/rad_gvv',
#     u'/Converted Telemetry/rad_oh',
#     u'/Converted Telemetry/rad_om',
#     u'/Converted Telemetry/rad_op',
#     u'/Converted Telemetry/rad_ov',
#     u'/Navigation/acs_mode',
#     u'/Navigation/att_ang',
#     u'/Navigation/beam_clat',
#     u'/Navigation/beam_clon',
#     u'/Navigation/cellatfoot',
#     u'/Navigation/cellonfoot',
#     u'/Navigation/celphi',
#     u'/Navigation/celtht',
#     u'/Navigation/glxlat',
#     u'/Navigation/glxlon',
#     u'/Navigation/moond',
#     u'/Navigation/moonglt',
#     u'/Navigation/orb_pos',
#     u'/Navigation/orb_vel',
#     u'/Navigation/scalt',
#     u'/Navigation/scat_beam_clat',
#     u'/Navigation/scat_beam_clon',
#     u'/Navigation/scat_latfoot',
#     u'/Navigation/scat_lonfoot',
#     u'/Navigation/scat_polarization_roll',
#     u'/Navigation/sclat',
#     u'/Navigation/sclon',
#     u'/Navigation/sund',
#     u'/Navigation/sunglt',
#     u'/Navigation/sunphi',
#     u'/Navigation/sunr',
#     u'/Navigation/suntht',
#     u'/Navigation/zang']}]}

# %% [markdown]
# ## Submit POST request and get token for status queries

# %%
params = json.dumps(request, separators=(',', ':'), sort_keys=True)
params
# Out:
# '{"email":"finch@jpl.nasa.gov","query":[{"bbox":"-175,-23,-100,23","compact":"False","datasetId":"PODAAC-AQR50-2SOCS","granuleIds":["Q2014153114100.L2_SCI_V5.0","Q2014153100300.L2_SCI_V5.0","Q2014153082500.L2_SCI_V5.0","Q2014153064700.L2_SCI_V5.0","Q2014153050900.L2_SCI_V5.0"],"variables":["/Aquarius Data/EIA_SSS_sens","/Aquarius Data/EIA_err","/Aquarius Data/IU_coupling_SSS_sens","/Aquarius Data/IU_coupling_err","/Aquarius Data/Kpc_HH_ant","/Aquarius Data/Kpc_HH_toa","/Aquarius Data/Kpc_HV_ant","/Aquarius Data/Kpc_HV_toa","/Aquarius Data/Kpc_VH_ant","/Aquarius Data/Kpc_VH_toa","/Aquarius Data/Kpc_VV_ant","/Aquarius Data/Kpc_VV_toa","/Aquarius Data/Kpc_total","/Aquarius Data/NEDT_3_SSS_sens","/Aquarius Data/NEDT_3_err","/Aquarius Data/NEDT_H_SSS_sens","/Aquarius Data/NEDT_H_err","/Aquarius Data/NEDT_V_SSS_sens","/Aquarius Data/NEDT_V_err","/Aquarius Data/RFI_level_SSS_sens","/Aquarius Data/RFI_level_err","/Aquarius Data/SSS","/Aquarius Data/SSS_matchup","/Aquarius Data/SSS_nolc","/Aquarius Data/SSS_unc","/Aquarius Data/SSS_unc_EIA","/Aquarius Data/SSS_unc_IU_coupling","/Aquarius Data/SSS_unc_NEDT_3","/Aquarius Data/SSS_unc_NEDT_H","/Aquarius Data/SSS_unc_NEDT_V","/Aquarius Data/SSS_unc_RFI_level","/Aquarius Data/SSS_unc_TbV_ice_contam","/Aquarius Data/SSS_unc_TbV_land_contam","/Aquarius Data/SSS_unc_galact_Ta","/Aquarius Data/SSS_unc_moon_Ta","/Aquarius Data/SSS_unc_ran","/Aquarius Data/SSS_unc_surface_temp","/Aquarius Data/SSS_unc_sys","/Aquarius Data/SSS_unc_wind_dir_rand","/Aquarius Data/SSS_unc_wind_speed_rand","/Aquarius Data/SSS_unc_wind_speed_syst","/Aquarius Data/anc_SSS_argo","/Aquarius Data/anc_SSS_hycom","/Aquarius Data/anc_Tb_dw","/Aquarius Data/anc_Tb_up","/Aquarius Data/anc_cwat","/Aquarius Data/anc_sm","/Aquarius Data/anc_subsurf_temp","/Aquarius Data/anc_surface_pressure","/Aquarius Data/anc_surface_temp","/Aquarius Data/anc_surface_temp_SSS_sens","/Aquarius Data/anc_surface_temp_err","/Aquarius Data/anc_swe","/Aquarius Data/anc_swh","/Aquarius Data/anc_trans","/Aquarius Data/anc_wind_dir","/Aquarius Data/anc_wind_speed","/Aquarius Data/density","/Aquarius Data/rad_Ta3","/Aquarius Data/rad_Ta30","/Aquarius Data/rad_TaH","/Aquarius Data/rad_TaH0","/Aquarius Data/rad_TaV","/Aquarius Data/rad_TaV0","/Aquarius Data/rad_TbH","/Aquarius Data/rad_TbH_nolc","/Aquarius Data/rad_TbH_rc","/Aquarius Data/rad_TbH_rc_nolc","/Aquarius Data/rad_TbV","/Aquarius Data/rad_TbV_ice_contam_SSS_sens","/Aquarius Data/rad_TbV_ice_contam_err","/Aquarius Data/rad_TbV_land_contam_SSS_sens","/Aquarius Data/rad_TbV_land_contam_err","/Aquarius Data/rad_TbV_nolc","/Aquarius Data/rad_TbV_rc","/Aquarius Data/rad_TbV_rc_nolc","/Aquarius Data/rad_Tb_consistency","/Aquarius Data/rad_Tb_consistency_nolc","/Aquarius Data/rad_Tf3","/Aquarius Data/rad_Tf30","/Aquarius Data/rad_TfH","/Aquarius Data/rad_TfH0","/Aquarius Data/rad_TfV","/Aquarius Data/rad_TfV0","/Aquarius Data/rad_dtb_sst_wspd_H","/Aquarius Data/rad_dtb_sst_wspd_V","/Aquarius Data/rad_exp_Ta3","/Aquarius Data/rad_exp_Ta3_hhh","/Aquarius Data/rad_exp_TaH","/Aquarius Data/rad_exp_TaH_hhh","/Aquarius Data/rad_exp_TaV","/Aquarius Data/rad_exp_TaV_hhh","/Aquarius Data/rad_exp_TbH","/Aquarius Data/rad_exp_TbH0","/Aquarius Data/rad_exp_TbV","/Aquarius Data/rad_exp_TbV0","/Aquarius Data/rad_far_rot_ang","/Aquarius Data/rad_galact_Ta_SSS_sens","/Aquarius Data/rad_galact_Ta_dir_3","/Aquarius Data/rad_galact_Ta_dir_H","/Aquarius Data/rad_galact_Ta_dir_V","/Aquarius Data/rad_galact_Ta_err","/Aquarius Data/rad_galact_Ta_ref_3","/Aquarius Data/rad_galact_Ta_ref_GO_H","/Aquarius Data/rad_galact_Ta_ref_GO_V","/Aquarius Data/rad_galact_Ta_ref_H","/Aquarius Data/rad_galact_Ta_ref_V","/Aquarius Data/rad_galact_dTa_H","/Aquarius Data/rad_galact_dTa_V","/Aquarius Data/rad_geo_rot_ang","/Aquarius Data/rad_hh_wind_speed","/Aquarius Data/rad_hhh_wind_speed","/Aquarius Data/rad_ice_frac","/Aquarius Data/rad_land_frac","/Aquarius Data/rad_moon_Ta_SSS_sens","/Aquarius Data/rad_moon_Ta_err","/Aquarius Data/rad_moon_ ...

# %%
params_url = urllib.urlencode({'query': params})
params_url
# Out:
# 'query=%7B%22email%22%3A%22finch%40jpl.nasa.gov%22%2C%22query%22%3A%5B%7B%22bbox%22%3A%22-175%2C-23%2C-100%2C23%22%2C%22compact%22%3A%22False%22%2C%22datasetId%22%3A%22PODAAC-AQR50-2SOCS%22%2C%22granuleIds%22%3A%5B%22Q2014153114100.L2_SCI_V5.0%22%2C%22Q2014153100300.L2_SCI_V5.0%22%2C%22Q2014153082500.L2_SCI_V5.0%22%2C%22Q2014153064700.L2_SCI_V5.0%22%2C%22Q2014153050900.L2_SCI_V5.0%22%5D%2C%22variables%22%3A%5B%22%2FAquarius+Data%2FEIA_SSS_sens%22%2C%22%2FAquarius+Data%2FEIA_err%22%2C%22%2FAquarius+Data%2FIU_coupling_SSS_sens%22%2C%22%2FAquarius+Data%2FIU_coupling_err%22%2C%22%2FAquarius+Data%2FKpc_HH_ant%22%2C%22%2FAquarius+Data%2FKpc_HH_toa%22%2C%22%2FAquarius+Data%2FKpc_HV_ant%22%2C%22%2FAquarius+Data%2FKpc_HV_toa%22%2C%22%2FAquarius+Data%2FKpc_VH_ant%22%2C%22%2FAquarius+Data%2FKpc_VH_toa%22%2C%22%2FAquarius+Data%2FKpc_VV_ant%22%2C%22%2FAquarius+Data%2FKpc_VV_toa%22%2C%22%2FAquarius+Data%2FKpc_total%22%2C%22%2FAquarius+Data%2FNEDT_3_SSS_sens%22%2C%22%2FAquarius+Data%2FNEDT_3_err%22%2C%22%2FAquarius+Data%2FNEDT_H_SSS_sens%22%2C%22%2FAquarius+Data%2FNEDT_H_err%22%2C%22%2FAquarius+Data%2FNEDT_V_SSS_sens%22%2C%22%2FAquarius+Data%2FNEDT_V_err%22%2C%22%2FAquarius+Data%2FRFI_level_SSS_sens%22%2C%22%2FAquarius+Data%2FRFI_level_err%22%2C%22%2FAquarius+Data%2FSSS%22%2C%22%2FAquarius+Data%2FSSS_matchup%22%2C%22%2FAquarius+Data%2FSSS_nolc%22%2C%22%2FAquarius+Data%2FSSS_unc%22%2C%22%2FAquarius+Data%2FSSS_unc_EIA%22%2C%22%2FAquarius+Data%2FSSS_unc_IU_coupling%22%2C%22%2FAquarius+Data%2FSSS_unc_NEDT_3%22%2C%22%2FAquarius+Data%2FSSS_unc_NEDT_H%22%2C%22%2FAquarius+Data%2FSSS_unc_NEDT_V%22%2C%22%2FAquarius+Data%2FSSS_unc_RFI_level%22%2C%22%2FAquarius+Data%2FSSS_unc_TbV_ice_contam%22%2C%22%2FAquarius+Data%2FSSS_unc_TbV_land_contam%22%2C%22%2FAquarius+Data%2FSSS_unc_galact_Ta%22%2C%22%2FAquarius+Data%2FSSS_unc_moon_Ta%22%2C%22%2FAquarius+Data%2FSSS_unc_ran%22%2C%22%2FAquarius+Data%2FSSS_unc_surface_temp%22%2C%22%2FAquarius+Data%2FSSS_unc_sys%22%2C%22%2FAquarius+Data%2FSSS_unc_wind_dir_rand%22%2C%22%2FAquarius+Data%2FSSS_unc_wind_speed_rand%22%2C%22%2FAquarius+Data%2FSSS_unc_wind_speed_syst%22%2C%22%2FAquarius+Data%2Fanc_SSS_argo%22%2C%22%2FAquarius+Data%2Fanc_SSS_hycom%22%2C%22%2FAquarius+Data%2Fanc_Tb_dw%22%2C%22%2FAquarius+Data%2Fanc_Tb_up%22%2C%22%2FAquarius+Data%2Fanc_cwat%22%2C%22%2FAquarius+Data%2Fanc_sm%22%2C%22%2FAquarius+Data%2Fanc_subsurf_temp%22%2C%22%2FAquarius+Data%2Fanc_surface_pressure%22%2C%22%2FAquarius+Data%2Fanc_surface_temp%22%2C%22%2FAquarius+Data%2Fanc_surface_temp_SSS_sens%22%2C%22%2FAquarius+Data%2Fanc_surface_temp_err%22%2C%22%2FAquarius+Data%2Fanc_swe%22%2C%22%2FAquarius+Data%2Fanc_swh%22%2C%22%2FAquarius+Data%2Fanc_trans%22%2C%22%2FAquarius+Data%2Fanc_wind_dir%22%2C%22%2FAquarius+Data%2Fanc_wind_speed%22%2C%22%2FAquarius+Data%2Fdensity%22%2C%22%2FAquarius+Data%2Frad_Ta3%22%2C%22%2FAquarius+Data%2Frad_Ta30%22%2C%22%2FAquarius+Data%2Frad_TaH%22%2C%22%2FAquarius+Data%2Frad_TaH0%22%2C%22%2FAquarius+Data%2Frad_TaV%22%2C%22%2FAquarius+Data%2Frad_TaV0%22%2C%22%2FAquarius+Data%2Frad_TbH%22%2C%22%2FAquarius+Data%2Frad_TbH_nolc%22%2C%22%2FAquarius+Data%2Frad_TbH_rc%22%2C%22%2FAquarius+Data%2Frad_TbH_rc_nolc%22%2C%22%2FAquarius+Data%2Frad_TbV%22%2C%22%2FAquarius+Data%2Frad_TbV_ice_contam_SSS_sens%22%2C%22%2FAquarius+Data%2Frad_TbV_ice_contam_err%22%2C%22%2FAquarius+Data%2Frad_TbV_land_contam_SSS_sens%22%2C%22%2FAquarius+Data%2Frad_TbV_land_contam_err%22%2C%22%2FAquarius+Data%2Frad_TbV_nolc%22%2C%22%2FAquarius+Data%2Frad_TbV_rc%22%2C%22%2FAquarius+Data%2Frad_TbV_rc_nolc%22%2C%22%2FAquarius+Data%2Frad_Tb_consistency%22%2C%22%2FAquarius+Data%2Frad_Tb_consistency_nolc%22%2C%22%2FAquarius+Data%2Frad_Tf3%22%2C%22%2FAquarius+Data%2Frad_Tf30%22%2C%22%2FAquarius+Data%2Frad_TfH%22%2C%22%2FAquarius+Data%2Frad_TfH0%22%2C%22%2FAquarius+Data%2Frad_TfV%22%2C%22%2FAquarius+Data%2Frad_TfV0%22%2C%22%2FAquarius+Data%2Frad_dtb_sst_wspd_H%22%2C%22%2FAquarius+Data%2Frad_dtb_sst_wspd_V%22%2C%22%2FAquarius+Data%2Frad_exp_Ta3%22%2C%22%2FAquarius+Data%2F ...

# %%
headers = {'Content-type': 'application/x-www-form-urlencoded',
          'Accept': '*'}
connection = httplib.HTTPSConnection('podaac.jpl.nasa.gov')
connection.request('POST', '/ws/subset/granule?request=submit',
                  params_url, headers)
response = connection.getresponse()
data = response.read()
result = json.loads(data)
token = result['token']
connection.close()
token
# Out:
# u'db2d36d6-fc94-4a0c-9be6-9b8c0904943a'

# %% [markdown]
# ## Track the progress of the request

# %%
while True:
    connection = httplib.HTTPSConnection('podaac.jpl.nasa.gov')
    connection.request('GET', '/ws/subset/status?token=' + token, params)
    response = connection.getresponse()
    data = response.read()
    connection.close()
    result = json.loads(data)
    status = result['status']
    
    if status != 'done':
        rstring = '{}: %{}/%{} granules'.format(result['status'],
                                                result['granuleCompleted'],
                                                result['totalNumGranule'])
        time.sleep(3)
        print rstring
    else:
        rstring = '{}: at {}'.format(result['status'], result['resultURLs'])
        print rstring
        break
# Out:
# processing: %0/%5 granules
# processing: %0/%5 granules
# processing: %0/%5 granules
# processing: %0/%5 granules
# processing: %0/%5 granules
# processing: %0/%5 granules
# processing: %0/%5 granules
# compressing: %5/%5 granules
# done: at [u'https://podaac-tools.jpl.nasa.gov/l2ss-download/db2d36d6-fc94-4a0c-9be6-9b8c0904943a/6a00eb13-4495-4147-90e9-d7edcd73e262.zip']

# %%
filename = 'results.zip'
urllib.urlretrieve(result['resultURLs'][0], filename)
# Out:
# ('results.zip', <httplib.HTTPMessage instance at 0x109c3dbd8>)

# %%
with ZipFile(filename, "r") as zip_ref:
    zip_ref.extractall('result')

# %%
os.listdir('result')
# Out:
# ['subsetted-Q2014153050900.L2_SCI_V5.0.hdf',
#  'subsetted-Q2014153064700.L2_SCI_V5.0.hdf',
#  'subsetted-Q2014153082500.L2_SCI_V5.0.hdf',
#  'subsetted-Q2014153100300.L2_SCI_V5.0.hdf',
#  'subsetted-Q2014153114100.L2_SCI_V5.0.hdf']
